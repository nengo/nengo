# %%
import numpy as np
import matplotlib.pyplot as plt
import nengo
import nengo.objects
import nengo.ipython
from nengo.helpers import tuning_curves
from nengo.matplotlib import rasterplot
plt.rc('axes', color_cycle="377EB8, E41A1C, 4DAF4A, 984EA3, FF7F00, 222222, A65628, E7298A")

def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1],[-1]], (n_neurons/2,1))
    intercepts *= encoders[:,0]
    return intercepts, encoders

# %matplotlib inline
nengo.ipython.hide_input()
# Out:
#         <a id="1676191096" href="javascript:toggle_input_1676191096()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1676191096;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1676191096 = document.getElementById("1676191096");
#                 var cell = link_1676191096;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1676191096;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1676191096 = cell.children[i];
#                 }
#                 input_1676191096.style.display = "none"; // hide
#
#                 toggle_input_1676191096 = function() {
#                     if (input_1676191096.style.display == "none") {
#                         input_1676191096.style.display = ""; // show
#                         link_1676191096.innerHTML = "Hide Input";
#                     } else {
#                         input_1676191096.style.display = "none"; // hide
#                         link_1676191096.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1676191096 = $("a[id='1676191096']");
#                 var cell_1676191096 = link_1676191096.parents("div.cell:first");
#                 var input_1676191096 = cell_1676191096.children("div.input");
#                 input_1676191096.hide();
#
#                 toggle_input_1676191096 = function() {
#                     if (input_1676191096.is(':hidden')) {
#                         input_1676191096.slideDown();
#                         link_1676191096[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1676191096.slideUp();
#                         link_1676191096[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 1: Representation
#
# ## Encoding
#
# Neural populations represent time-varying signals. A signal is a vector of real numbers of arbitrary length.

# %%
model = nengo.Model("NEF summary")
model.make_node("Input signal", output=lambda t: t * 2 - 1)
model.probe("Input signal")

# %%
sim = model.simulator()
sim.run(1.0)

plt.plot(sim.data(model.t), sim.data("Input signal"), lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
nengo.ipython.hide_input()
# Out:
#         <a id="847948445" href="javascript:toggle_input_847948445()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_847948445;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_847948445 = document.getElementById("847948445");
#                 var cell = link_847948445;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_847948445;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_847948445 = cell.children[i];
#                 }
#                 input_847948445.style.display = "none"; // hide
#
#                 toggle_input_847948445 = function() {
#                     if (input_847948445.style.display == "none") {
#                         input_847948445.style.display = ""; // show
#                         link_847948445.innerHTML = "Hide Input";
#                     } else {
#                         input_847948445.style.display = "none"; // hide
#                         link_847948445.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_847948445 = $("a[id='847948445']");
#                 var cell_847948445 = link_847948445.parents("div.cell:first");
#                 var input_847948445 = cell_847948445.children("div.input");
#                 input_847948445.hide();
#
#                 toggle_input_847948445 = function() {
#                     if (input_847948445.is(':hidden')) {
#                         input_847948445.slideDown();
#                         link_847948445[0].innerHTML = "Hide Input";
#                     } else {
#                         input_847948445.slideUp();
#                         link_847948445[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations based on each neuron's *tuning curve* (which is similar to the I-F curve, if you're familiar with that).
#
# This curve describes how much a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)
model.make_ensemble("A", nengo.LIF(8), 1, 
                    intercepts=intercepts,
                    max_rates=nengo.objects.Uniform(80, 100), 
                    encoders=encoders)

# %%
sim = model.simulator()

eval_points, activities = tuning_curves(sim.get("A"))
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
nengo.ipython.hide_input()
# Out:
#         <a id="801049003" href="javascript:toggle_input_801049003()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_801049003;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_801049003 = document.getElementById("801049003");
#                 var cell = link_801049003;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_801049003;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_801049003 = cell.children[i];
#                 }
#                 input_801049003.style.display = "none"; // hide
#
#                 toggle_input_801049003 = function() {
#                     if (input_801049003.style.display == "none") {
#                         input_801049003.style.display = ""; // show
#                         link_801049003.innerHTML = "Hide Input";
#                     } else {
#                         input_801049003.style.display = "none"; // hide
#                         link_801049003.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_801049003 = $("a[id='801049003']");
#                 var cell_801049003 = link_801049003.parents("div.cell:first");
#                 var input_801049003 = cell_801049003.children("div.input");
#                 input_801049003.hide();
#
#                 toggle_input_801049003 = function() {
#                     if (input_801049003.is(':hidden')) {
#                         input_801049003.slideDown();
#                         link_801049003[0].innerHTML = "Hide Input";
#                     } else {
#                         input_801049003.slideUp();
#                         link_801049003[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal and observe their spiking activity.

# %%
model.connect("Input signal", "A")
model.probe("A.spikes")

# %%
sim = model.simulator()
sim.run(1)

ax = plt.subplot(1,1,1)
rasterplot(sim.data(model.t), sim.data("A.spikes"), ax)
ax.set_xlim(0, 1)
ax.set_ylabel('Neuron')
ax.set_xlabel('Time (s)')
nengo.ipython.hide_input()
# Out:
#         <a id="1823884756" href="javascript:toggle_input_1823884756()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1823884756;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1823884756 = document.getElementById("1823884756");
#                 var cell = link_1823884756;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1823884756;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1823884756 = cell.children[i];
#                 }
#                 input_1823884756.style.display = "none"; // hide
#
#                 toggle_input_1823884756 = function() {
#                     if (input_1823884756.style.display == "none") {
#                         input_1823884756.style.display = ""; // show
#                         link_1823884756.innerHTML = "Hide Input";
#                     } else {
#                         input_1823884756.style.display = "none"; // hide
#                         link_1823884756.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1823884756 = $("a[id='1823884756']");
#                 var cell_1823884756 = link_1823884756.parents("div.cell:first");
#                 var input_1823884756 = cell_1823884756.children("div.input");
#                 input_1823884756.hide();
#
#                 toggle_input_1823884756 = function() {
#                     if (input_1823884756.is(':hidden')) {
#                         input_1823884756.slideDown();
#                         link_1823884756[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1823884756.slideUp();
#                         link_1823884756[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Decoding
#
# We can estimate the input signal originally encoded. To do this, we first filter the spike train with a temporal filter.

# %%
# Hack to remove probe, should make it possible to probe again
model.get("A").probes['spikes'] = []
del model.get("A").connections_out[0]
del model.probed["A.spikes"]
# End hack
model.probe("A.spikes", filter=0.01)

# %%
sim = model.simulator()
sim.run(1)

scale = 0.2
for i in xrange(model.get("A").n_neurons):
    plt.plot(sim.data(model.t), sim.data("A.spikes")[:,i] - i*scale)
plt.xlim(0, 1)
plt.ylim(scale * (-model.get("A").n_neurons+1), scale)
plt.ylabel("Neuron")
plt.yticks(np.arange(scale/1.8, (-model.get("A").n_neurons+1) * scale, -scale), np.arange(model.get("A").n_neurons))
nengo.ipython.hide_input()
# Out:
#         <a id="1269795135" href="javascript:toggle_input_1269795135()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1269795135;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1269795135 = document.getElementById("1269795135");
#                 var cell = link_1269795135;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1269795135;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1269795135 = cell.children[i];
#                 }
#                 input_1269795135.style.display = "none"; // hide
#
#                 toggle_input_1269795135 = function() {
#                     if (input_1269795135.style.display == "none") {
#                         input_1269795135.style.display = ""; // show
#                         link_1269795135.innerHTML = "Hide Input";
#                     } else {
#                         input_1269795135.style.display = "none"; // hide
#                         link_1269795135.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1269795135 = $("a[id='1269795135']");
#                 var cell_1269795135 = link_1269795135.parents("div.cell:first");
#                 var input_1269795135 = cell_1269795135.children("div.input");
#                 input_1269795135.hide();
#
#                 toggle_input_1269795135 = function() {
#                     if (input_1269795135.is(':hidden')) {
#                         input_1269795135.slideDown();
#                         link_1269795135[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1269795135.slideUp();
#                         link_1269795135[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains with decoding weights and sum them together.
#
# The decoding weights are determined by minimizing the squared difference between the decoded estimate and the actual input signal.

# %%
model.probe("A", filter=0.01)

# %%
sim = model.simulator()
sim.run(1)

plt.plot(sim.data(model.t), sim.data("Input signal"), label="Input signal")
plt.plot(sim.data(model.t), sim.data("A"), label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
nengo.ipython.hide_input()
# Out:
#         <a id="983472361" href="javascript:toggle_input_983472361()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_983472361;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_983472361 = document.getElementById("983472361");
#                 var cell = link_983472361;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_983472361;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_983472361 = cell.children[i];
#                 }
#                 input_983472361.style.display = "none"; // hide
#
#                 toggle_input_983472361 = function() {
#                     if (input_983472361.style.display == "none") {
#                         input_983472361.style.display = ""; // show
#                         link_983472361.innerHTML = "Hide Input";
#                     } else {
#                         input_983472361.style.display = "none"; // hide
#                         link_983472361.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_983472361 = $("a[id='983472361']");
#                 var cell_983472361 = link_983472361.parents("div.cell:first");
#                 var input_983472361 = cell_983472361.children("div.input");
#                 input_983472361.hide();
#
#                 toggle_input_983472361 = function() {
#                     if (input_983472361.is(':hidden')) {
#                         input_983472361.slideDown();
#                         link_983472361[0].innerHTML = "Hide Input";
#                     } else {
#                         input_983472361.slideUp();
#                         link_983472361[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases as the number of neurons increases.

# %%
model = nengo.Model("NEF summary")
model.make_node("Input signal", output=lambda t: t * 2 - 1)
model.probe("Input signal")
intercepts, encoders = aligned(30, 0.95)
model.make_ensemble("A", nengo.LIF(30), 1, 
                    intercepts=intercepts,
                    max_rates=nengo.objects.Uniform(80, 100), 
                    encoders=encoders)
model.connect("Input signal", "A")
model.probe("A.spikes")
model.probe("A", filter=0.01)

# %%
sim = model.simulator()
sim.run(1)

plt.figure(figsize=(15,3.5))

plt.subplot(1,3,1)
eval_points, activities = tuning_curves(sim.get("A"))
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)");

ax = plt.subplot(1,3,2)
rasterplot(sim.data(model.t), sim.data("A.spikes"), ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1,3,3)
plt.plot(sim.data(model.t), sim.data("Input signal"), label="Input signal")
plt.plot(sim.data(model.t), sim.data("A"), label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
nengo.ipython.hide_input()
# Out:
#         <a id="1692805786" href="javascript:toggle_input_1692805786()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1692805786;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1692805786 = document.getElementById("1692805786");
#                 var cell = link_1692805786;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1692805786;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1692805786 = cell.children[i];
#                 }
#                 input_1692805786.style.display = "none"; // hide
#
#                 toggle_input_1692805786 = function() {
#                     if (input_1692805786.style.display == "none") {
#                         input_1692805786.style.display = ""; // show
#                         link_1692805786.innerHTML = "Hide Input";
#                     } else {
#                         input_1692805786.style.display = "none"; // hide
#                         link_1692805786.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1692805786 = $("a[id='1692805786']");
#                 var cell_1692805786 = link_1692805786.parents("div.cell:first");
#                 var input_1692805786 = cell_1692805786.children("div.input");
#                 input_1692805786.hide();
#
#                 toggle_input_1692805786 = function() {
#                     if (input_1692805786.is(':hidden')) {
#                         input_1692805786.slideDown();
#                         link_1692805786[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1692805786.slideUp();
#                         link_1692805786[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
from nengo.helpers import white_noise
from nengo.objects import Uniform
model = nengo.Model("NEF summary")
model.make_node("Input signal", output=white_noise(1, 5, seed=60))
model.probe("Input signal")
intercepts, encoders = aligned(30, 0.8)
model.make_ensemble("A", nengo.LIF(30), 1, 
                    intercepts=intercepts,
                    max_rates=nengo.objects.Uniform(80, 100), 
                    encoders=encoders)
model.connect("Input signal", "A")
model.probe("A.spikes")
model.probe("A", filter=0.01)

# %%
sim = model.simulator()
sim.run(1)

plt.figure(figsize=(10,3.5))
plt.subplot(1,2,1)
plt.plot(sim.data(model.t), sim.data("Input signal"), label="Input signal")
plt.plot(sim.data(model.t), sim.data("A"), label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1,2,2)
rasterplot(sim.data(model.t), sim.data("A.spikes"), ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
nengo.ipython.hide_input()
# Out:
#         <a id="102995025" href="javascript:toggle_input_102995025()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_102995025;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_102995025 = document.getElementById("102995025");
#                 var cell = link_102995025;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_102995025;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_102995025 = cell.children[i];
#                 }
#                 input_102995025.style.display = "none"; // hide
#
#                 toggle_input_102995025 = function() {
#                     if (input_102995025.style.display == "none") {
#                         input_102995025.style.display = ""; // show
#                         link_102995025.innerHTML = "Hide Input";
#                     } else {
#                         input_102995025.style.display = "none"; // hide
#                         link_102995025.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_102995025 = $("a[id='102995025']");
#                 var cell_102995025 = link_102995025.parents("div.cell:first");
#                 var input_102995025 = cell_102995025.children("div.input");
#                 input_102995025.hide();
#
#                 toggle_input_102995025 = function() {
#                     if (input_102995025.is(':hidden')) {
#                         input_102995025.slideDown();
#                         link_102995025[0].innerHTML = "Hide Input";
#                     } else {
#                         input_102995025.slideUp();
#                         link_102995025[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# In fact, we can decode arbitrary transformations of the input signal, not just the signal itself.
#
# Let's decode the square of our white noise input.

# %%
from nengo.helpers import white_noise
from nengo.objects import Uniform

model = nengo.Model("NEF summary")
model.make_node("Input signal", output=white_noise(1, 5, seed=60))
model.probe("Input signal")
intercepts, encoders = aligned(30)
model.make_ensemble("A", nengo.LIF(30), 1, 
                    intercepts=intercepts,
                    max_rates=nengo.objects.Uniform(80, 100), 
                    encoders=encoders)
model.connect("Input signal", "A")
model.probe("A.spikes")
model.probe("A", filter=0.01)
model.get("A").connections_out[1].function = np.square

# %%
sim = model.simulator()
sim.run(1)

plt.figure(figsize=(10,3.5))
plt.subplot(1,2,1)
plt.plot(sim.data(model.t), sim.data("Input signal"), label="Input signal")
plt.plot(sim.data(model.t), sim.data("A"), label="Decoded esimate")
plt.plot(sim.data(model.t), np.square(sim.data("Input signal")), label="Input signal squared")
plt.legend(loc="best", fontsize='medium')
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1,2,2)
rasterplot(sim.data(model.t), sim.data("A.spikes"))
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
nengo.ipython.hide_input()
# Out:
#         <a id="806650311" href="javascript:toggle_input_806650311()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_806650311;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_806650311 = document.getElementById("806650311");
#                 var cell = link_806650311;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_806650311;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_806650311 = cell.children[i];
#                 }
#                 input_806650311.style.display = "none"; // hide
#
#                 toggle_input_806650311 = function() {
#                     if (input_806650311.style.display == "none") {
#                         input_806650311.style.display = ""; // show
#                         link_806650311.innerHTML = "Hide Input";
#                     } else {
#                         input_806650311.style.display = "none"; // hide
#                         link_806650311.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_806650311 = $("a[id='806650311']");
#                 var cell_806650311 = link_806650311.parents("div.cell:first");
#                 var input_806650311 = cell_806650311.children("div.input");
#                 input_806650311.hide();
#
#                 toggle_input_806650311 = function() {
#                     if (input_806650311.is(':hidden')) {
#                         input_806650311.slideDown();
#                         link_806650311[0].innerHTML = "Hide Input";
#                     } else {
#                         input_806650311.slideUp();
#                         link_806650311[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same. The only difference is how we're interpreting those spikes.
#
# # Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time, and decode transformations of those signals.
#
# In the principle of transformation, we combine these two steps together in order to project transformations of encoded signals from one population of neurons to another population.
#
# Suppose we are representing a sine wave.

# %%
from nengo.objects import Uniform

model = nengo.Model("NEF summary")
model.make_node("Input signal", output=lambda t: np.sin(np.pi*t))
intercepts, encoders = aligned(30)
model.make_ensemble("A", nengo.LIF(30), dimensions=1, 
                    intercepts=intercepts, encoders=encoders,
                    max_rates=nengo.objects.Uniform(80, 100))
model.connect("Input signal", "A")
model.probe("A.spikes")
model.probe("A", filter=0.01)

# %%
sim = model.simulator()
sim.run(2)

plt.figure(figsize=(10,3.5))
plt.subplot(1,2,1)
plt.plot(sim.data(model.t), sim.data("A"))
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1,2,2)
rasterplot(sim.data(model.t), sim.data("A.spikes"), ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
nengo.ipython.hide_input()
# Out:
#         <a id="1832373522" href="javascript:toggle_input_1832373522()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1832373522;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1832373522 = document.getElementById("1832373522");
#                 var cell = link_1832373522;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1832373522;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1832373522 = cell.children[i];
#                 }
#                 input_1832373522.style.display = "none"; // hide
#
#                 toggle_input_1832373522 = function() {
#                     if (input_1832373522.style.display == "none") {
#                         input_1832373522.style.display = ""; // show
#                         link_1832373522.innerHTML = "Hide Input";
#                     } else {
#                         input_1832373522.style.display = "none"; // hide
#                         link_1832373522.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1832373522 = $("a[id='1832373522']");
#                 var cell_1832373522 = link_1832373522.parents("div.cell:first");
#                 var input_1832373522 = cell_1832373522.children("div.input");
#                 input_1832373522.hide();
#
#                 toggle_input_1832373522 = function() {
#                     if (input_1832373522.is(':hidden')) {
#                         input_1832373522.slideDown();
#                         link_1832373522[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1832373522.slideUp();
#                         link_1832373522[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal involve solving for the usual decoders, and scaling those decoding weights.

# %%
model.make_ensemble("-A", nengo.LIF(30), dimensions=1, 
                    intercepts=intercepts, encoders=encoders,
                    max_rates=nengo.objects.Uniform(80, 100))
model.connect("A", "-A", function=np.negative)
model.probe("-A.spikes")
model.probe("-A", filter=0.01)

# %%
sim = model.simulator()
sim.run(2)

plt.figure(figsize=(10,5))
plt.subplot(2,2,1)
plt.plot(sim.data(model.t), sim.data("A"))
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2,2,3)
plt.plot(sim.data(model.t), sim.data("-A"))
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2,2,2)
rasterplot(sim.data(model.t), sim.data("A.spikes"), ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2,2,4)
rasterplot(sim.data(model.t), sim.data("-A.spikes"), ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
nengo.ipython.hide_input()
# Out:
#         <a id="1548616389" href="javascript:toggle_input_1548616389()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1548616389;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1548616389 = document.getElementById("1548616389");
#                 var cell = link_1548616389;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1548616389;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1548616389 = cell.children[i];
#                 }
#                 input_1548616389.style.display = "none"; // hide
#
#                 toggle_input_1548616389 = function() {
#                     if (input_1548616389.style.display == "none") {
#                         input_1548616389.style.display = ""; // show
#                         link_1548616389.innerHTML = "Hide Input";
#                     } else {
#                         input_1548616389.style.display = "none"; // hide
#                         link_1548616389.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1548616389 = $("a[id='1548616389']");
#                 var cell_1548616389 = link_1548616389.parents("div.cell:first");
#                 var input_1548616389 = cell_1548616389.children("div.input");
#                 input_1548616389.hide();
#
#                 toggle_input_1548616389 = function() {
#                     if (input_1548616389.is(':hidden')) {
#                         input_1548616389.slideDown();
#                         link_1548616389[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1548616389.slideUp();
#                         link_1548616389[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve solving for a new set of decoding weights.

# %%
model.make_ensemble("-A^2", nengo.LIF(30), dimensions=1,
                    intercepts=intercepts, encoders=encoders,
                    max_rates=nengo.objects.Uniform(80, 100))
model.connect("-A", "-A^2", function=np.square)
model.probe("-A^2.spikes")
model.probe("-A^2", filter=0.02)

# %%
sim = model.simulator()
sim.run(2)

plt.figure(figsize=(10,6.5))
plt.subplot(3,2,1)
plt.plot(sim.data(model.t), sim.data("A"))
plt.axhline(0, color='k')
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3,2,3)
plt.plot(sim.data(model.t), sim.data("-A"))
plt.axhline(0, color='k')
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3,2,5)
plt.plot(sim.data(model.t), sim.data("-A^2"))
plt.axhline(0, color='k')
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3,2,2)
rasterplot(sim.data(model.t), sim.data("A.spikes"), ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3,2,4)
rasterplot(sim.data(model.t), sim.data("-A.spikes"), ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3,2,6)
rasterplot(sim.data(model.t), sim.data("-A^2.spikes"), ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
nengo.ipython.hide_input()
# Out:
#         <a id="1417473795" href="javascript:toggle_input_1417473795()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1417473795;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1417473795 = document.getElementById("1417473795");
#                 var cell = link_1417473795;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1417473795;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1417473795 = cell.children[i];
#                 }
#                 input_1417473795.style.display = "none"; // hide
#
#                 toggle_input_1417473795 = function() {
#                     if (input_1417473795.style.display == "none") {
#                         input_1417473795.style.display = ""; // show
#                         link_1417473795.innerHTML = "Hide Input";
#                     } else {
#                         input_1417473795.style.display = "none"; // hide
#                         link_1417473795.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1417473795 = $("a[id='1417473795']");
#                 var cell_1417473795 = link_1417473795.parents("div.cell:first");
#                 var input_1417473795 = cell_1417473795.children("div.input");
#                 input_1417473795.hide();
#
#                 toggle_input_1417473795 = function() {
#                     if (input_1417473795.is(':hidden')) {
#                         input_1417473795.slideDown();
#                         link_1417473795[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1417473795.slideUp();
#                         link_1417473795[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# # Principle 3: Dynamics
#
# So far, we've been considering the values represented by ensembles as generic "signals." However, if we think of them instead as state variables in a dynamical system, then we can apply the methods of control theory to brain models.
#
# In order to get interesting dynamics, we connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmoic oscillator. All it needs is a bit of input to get started.

# %%
model = nengo.Model("NEF summary")
model.make_node('Input signal', 
                output=lambda t: [1,0] if t < 0.1 else [0,0])
model.make_ensemble('Oscillator', nengo.LIF(200), dimensions=2)
model.connect('Input signal','Oscillator')
model.connect('Oscillator', 'Oscillator', 
              transform=[[1,1],[-1,1]], filter=0.1)
model.probe('Oscillator', filter=0.02)

# %%
sim = model.simulator()
sim.run(3)

plt.figure(figsize=(10,3.5))
plt.subplot(1,2,1)
plt.plot(sim.data(model.t), sim.data('Oscillator'))
plt.ylim(-1.2, 1.2)
plt.xlabel('Time (s)')

plt.subplot(1,2,2)
plt.plot(sim.data('Oscillator')[:,0], sim.data('Oscillator')[:,1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel('$x_1$')
plt.ylabel('$x_2$')
nengo.ipython.hide_input()
# Out:
#         <a id="1386608999" href="javascript:toggle_input_1386608999()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1386608999;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1386608999 = document.getElementById("1386608999");
#                 var cell = link_1386608999;
#                 while (cell.className.split(' ')[0] != "cell") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1386608999;
#                 for (var i = 0; i < cell.children.length; i++) {
#                     if (cell.children[i].className.split(' ')[0] == "input")
#                         input_1386608999 = cell.children[i];
#                 }
#                 input_1386608999.style.display = "none"; // hide
#
#                 toggle_input_1386608999 = function() {
#                     if (input_1386608999.style.display == "none") {
#                         input_1386608999.style.display = ""; // show
#                         link_1386608999.innerHTML = "Hide Input";
#                     } else {
#                         input_1386608999.style.display = "none"; // hide
#                         link_1386608999.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1386608999 = $("a[id='1386608999']");
#                 var cell_1386608999 = link_1386608999.parents("div.cell:first");
#                 var input_1386608999 = cell_1386608999.children("div.input");
#                 input_1386608999.hide();
#
#                 toggle_input_1386608999 = function() {
#                     if (input_1386608999.is(':hidden')) {
#                         input_1386608999.slideDown();
#                         link_1386608999[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1386608999.slideUp();
#                         link_1386608999[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
