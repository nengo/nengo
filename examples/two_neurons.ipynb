# %% [markdown]
# # Nengo Example: Two Neurons
#
# This demo shows how to construct and manipulate a complementary pair of neurons.
#
# These are leaky integrate-and-fire (LIF) neurons. The neuron tuning properties have been selected so there is one ‘on’ and one ‘off’ neuron.
#
# One neuron will increase for positive input, and the other will decrease. This can be thought of as the simplest population that is able to give a reasonable representation of a scalar value.

# %% [markdown]
# ## Step 1: Create the neurons

# %%
import nengo
from nengo.utils.distributions import Uniform

model = nengo.Network(label='Two Neurons')
with model:
    neurons = nengo.Ensemble(2, dimensions=1,  # Representing a scalar
                             intercepts=Uniform(-.5, -.5),  # Set the intercepts at .5
                             max_rates=Uniform(100,100),  # Set the max firing rate at 100hz
                             encoders=[[1],[-1]])  # One 'on' and one 'off' neuron

# %% [markdown]
# ## Step 2: Create input for the model
#
# Create an input node generating a sine wave.

# %%
import numpy as np
with model:
    sin = nengo.Node(lambda t: np.sin(8 * t))

# %% [markdown]
# ## Step 3: Connect the network elements

# %%
with model:
    nengo.Connection(sin, neurons, synapse=0.01)

# %% [markdown]
# ## Step 4: Probe outputs
#
# Anything that is probed will collect the data it produces over time, allowing us to analyze and visualize it later.

# %%
with model:
    sin_probe = nengo.Probe(sin)  # The original input
    spikes = nengo.Probe(neurons, 'spikes')  # Raw spikes from each neuron
    voltage = nengo.Probe(neurons, 'voltage')  # Subthreshold soma voltages of the neurons
    filtered = nengo.Probe(neurons, synapse=0.01)  # Spikes filtered by a 10ms post-synaptic filter

# %% [markdown]
# ## Step 5: Run the model

# %%
sim = nengo.Simulator(model)  # Create a simulator
sim.run(1)  # Run it for 5 seconds

# %% [markdown]
# ## Step 6: Plot the results

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Plot the decoded output of the ensemble
plt.plot(sim.trange(), sim.data[filtered])
plt.plot(sim.trange(), sim.data[sin_probe])
plt.xlim(0, 1)

# Plot the spiking output of the ensemble
from nengo.utils.matplotlib import rasterplot
plt.figure(figsize=(10, 8))
plt.subplot(221)
rasterplot(sim.trange(), sim.data[spikes], colors=[(1, 0, 0), (0, 0, 0)])
plt.xlim(0, 1)
plt.yticks((0, 1), ("On neuron", "Off neuron"))

# Plot the soma voltages of the neurons
plt.subplot(222)
plt.plot(sim.trange(), sim.data[voltage][:, 0] + 1, 'r')
plt.plot(sim.trange(), sim.data[voltage][:, 1], 'k')
plt.yticks(())
plt.axis([0, 1, 0, 2])
plt.subplots_adjust(wspace=0.05)

# %% [markdown]
# The top graph shows that the input signal in green and the filtered output spikes from the two neurons population in blue.  The spikes (that are filtered) from the 'on' and 'off' neurons are shown in the bottom graph on the left.  On the right are the subthreshold voltages for the neurons.

# %%
rasterplot??

# %%
plt.plot(sim.trange(), sim.data[voltage][:, 0] + 1, 'r')\

# %%
rasterplot(sim.trange(), sim.data[spikes], colors=[(1, 0, 0), (0, 0, 0)])

# %%
plt.plot(sim.trange(), sim.data[filtered])
plt.plot(sim.trange(), sim.data[sin_probe])

# %%
plt.plot(sim.trange(), sim.data[voltage])
plt.plot(sim.trange(), sim.data[sin_probe])

# %%
plt.plot(sim.trange(), sim.data[voltage])
plt.plot(sim.trange(), sim.data[sin_probe])

# %%
plt.plot(sim.trange(), sim.data[voltage])
#         0.71471612,  0.77048018,  0.82399281,  0.87536608,  0.92470638,
#         0.97211478,  0.        ,  0.        ,  0.03696587,  0.13089517,
#         0.22065965,  0.30646677,  0.38851356,  0.46698717,  0.54206537,
#         0.613917  ,  0.68270242,  0.74857394,  0.81167622,  0.87214668,
#         0.93011578,  0.98570748,  0.        ,  0.        ,  0.07587525,
#         0.17625117,  0.27212319,  0.36371516,  0.45123973,  0.53489886,
#         0.61488441,  0.69137858,  0.76455445,  0.83457641,  0.9016006 ,
#         0.96577531,  0.        ,  0.        ,  0.04908377,  0.1578747 ,
#         0.26171938,  0.36086334,  0.4555398 ,  0.5459703 ,  0.63236524,
#         0.71492451,  0.79383795,  0.86928588,  0.94143958,  0.        ,
#         0.        ,  0.01773984,  0.13436288,  0.24562247,  0.35178461,
#         0.45310195,  0.54981449,  0.64215021,  0.73032564,  0.81454647,
#         0.89500807,  0.97189602,  0.        ,  0.        ,  0.07594552,
#         0.19555985,  0.30963052,  0.41843216,  0.52222564,  0.62125875,
#         0.71576686,  0.80597357,  0.89209124,  0.97432161,  0.        ,
#         0.        ,  0.08619786,  0.21036946,  0.32873706,  0.44158797,
#         0.54919512,  0.65181777,  0.74970219,  0.8430823 ,  0.93218032,
#         0.        ,  0.        ,  0.02679332,  0.15822288,  0.28345246,
#         0.40278893,  0.51652376,  0.62493382,  0.72828215,  0.82681857,
#         0.92078042,  0.        ,  0.        ,  0.01581246,  0.15170048,
#         0.28112967,  0.40441958,  0.52187375,  0.63378051,  0.74041379,
#         0.84203376,  0.9388876 ,  0.        ,  0.        ,  0.04728675,
#         0.18510193,  0.31632339,  0.4412772 ,  0.56027309,  0.67360531,
#         0.78155335,  0.88438275,  0.9823457 ,  0.        ,  0.        ,
#         0.11593952,  0.25338729,  0.38421888,  0.50876128,  0.62732512,
#         0.74020548,  0.84768268,  0.95002298,  0.        ,  0.        ,
#         0.07084262,  0.21293374,  0.34813766,  0.47679477,  0.59922844,
#         0.71574585,  0.8266388 ,  0.9321845 ,  0.        ,  0.        ,
#         0.04791425,  0.19314532,  0.33129196,  0.4627043 ,  0.58771494,
#         0.70663986,  0.81977923,  0.92741819,  0.        ,  0.        ,
#         0.04341868,  0.19046036,  0.3302857 ,  0.46325133,  0.58969603,
#         0.70994165,  0.82429393,  0.93304331,  0.        ,  0.        ,
#         0.05298823,  0.2007194 ,  0.34115751,  0.47466297,  0.60157812,
#         0.72222822,  0.83692223,  0.94595369,  0.        ,  0.        ,
#         0.07229489,  0.21980336,  0.35998708,  0.49320796,  0.61980986,
#         0.74011939,  0.85444687,  0.96308708,  0.        ,  0.        ,
#         0.09727944,  0.24385124,  0.38310196,  0.51539332,  0.64106896,
#         0.76045535,  0.87386263,  0.98158543,  0.        ,  0.        ])

# %%
sim.data[voltage].size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-4e676585411e> in <module>()
# ----> 1 sim.data[voltage].size()
#
# TypeError: 'int' object is not callable

# %%
size(sim.data[voltage][:,0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-04b381d51f78> in <module>()
# ----> 1 size(sim.data[voltage][:,0])
#
# NameError: name 'size' is not defined

# %%
sim.data[voltage][:,0].shape
# Out:
# (1000,)
