# %% [markdown]
# # Nengo Example: Two Neurons
#
# This demo shows how to construct and manipulate a complementary pair of neurons.
#
# These are leaky integrate-and-fire (LIF) neurons. The neuron tuning properties have been selected so there is one ‘on’ and one ‘off’ neuron.
#
# One neuron will increase for positive input, and the other will decrease. This can be thought of as the simplest population that is able to give a reasonable representation of a scalar value.

# %% [markdown]
# ## Step 1: Create the neurons

# %%
import nengo
from nengo.objects import Uniform

model = nengo.Model('Two Neurons')

model.make_ensemble('Neurons', 
                    nengo.LIF(2), #
                    dimensions=1, # Representing a scalar
                    intercepts=Uniform(-.5, -.5), #Set the intercepts at .5
                    max_rates=Uniform(100,100), #Set the max firing rate at 100hz
                    encoders=[[1],[-1]]) #One 'on' and one 'off' neuron

# %% [markdown]
# ## Step 2: Create input for the model
#
# Create an input node generating a sine wave.

# %%
import numpy as np

model.make_node('sin', output=np.sin)

# %% [markdown]
# ## Step 3: Connect the network elements

# %%
model.connect('sin', 'Neurons')
# Out:
# sin>Neurons (DecodedConnection)

# %% [markdown]
# ## Step 4: Probe outputs
#
# Anything that is probed will collect the data it produces over time, allowing us to analyze and visualize it later.

# %%
model.probe('Neurons.spikes') # Raw spikes from each neuron
#TODO: model.probe('Neurons.voltages') # Subthreshold soma voltages of the neurons
model.probe('Neurons', filter = 0.01) # Spikes filtered by a 10ms post-synaptic filter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-14e84a957fc6> in <module>()
# ----> 1 model.probe('Neurons.spikes') # Raw spikes from each neuron
#       2 #TODO: model.probe('Neurons.voltages') # Subthreshold soma voltages of the neurons
#       3 model.probe('Neurons', filter = 0.01) # Spikes filtered by a 10ms post-synaptic filter
#
# /Users/celiasmi/Documents/nengo/nengo/nengo/model.pyc in probe(self, target, sample_every, filter)
#     688             if len(s) > 1:
#     689                 obj = self.get('.'.join(s[:-1]))
# --> 690                 p = obj.probe(s[-1], sample_every, filter)
#     691             else:
#     692                 obj = self.get(target)
#
# /Users/celiasmi/Documents/nengo/nengo/nengo/objects.py in probe(self, to_probe, sample_every, filter)
#     292         elif to_probe == 'spikes':
#     293             probe = Probe(self.name + '.spikes', sample_every)
# --> 294             connection = connections.NonlinearityConnection(self.neurons, probe,
#     295                                     filter=None, transform=np.eye(self.n_neurons))
#     296             self.connections_out.append(connection)
#
# AttributeError: 'module' object has no attribute 'NonlinearityConnection'

# %% [markdown]
# ## Step 5: Run the model

# %%
sim = model.simulator() #Create a simulator
sim.run(5) # Run it for 5 seconds

# %% [markdown]
# ## Step 6: Plot the results

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Plot the decoded output of the ensemble
t = sim.data(model.t) #Get the time steps
plt.plot(t, sim.data('2D Population'), label="2D output")
plt.plot(t, sim.data('A'), label="A output")
plt.plot(t, sim.data('sin'), 'k', label="Sine")
plt.legend()
# Out:
# ERROR: Line magic function `%matplotlib` not found.

# %% [markdown]
# The graph shows that the input signal (Sine), the output from the 1D population (A output), and the 2D population (blue line) are all equal.  The other dimension in the 2D population is shown in green.
